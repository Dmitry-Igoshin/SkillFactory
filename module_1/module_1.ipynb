# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from collections import Counter

# %%
Movies = pd.read_csv('movie_bd_v5.csv')
Movies.sample(5)
# Out:
#         imdb_id    budget    revenue  ... release_date vote_average release_year
# 1220  tt2404311  30000000   36894225  ...    9/13/2013          6.1         2013
# 1117  tt0251127  50000000  177371441  ...     2/7/2003          6.2         2003
# 63    tt3569230  25000000   42972994  ...     9/9/2015          6.7         2015
# 799   tt1152398  17000000   43165571  ...    1/21/2011          6.0         2011
# 1025  tt1586265  40000000   79700000  ...    5/17/2012          5.7         2012
#
# [5 rows x 14 columns]

# %%
Movies.describe()
# Out:
#              budget       revenue      runtime  vote_average  release_year
# count  1.889000e+03  1.889000e+03  1889.000000   1889.000000   1889.000000
# mean   5.431083e+07  1.553653e+08   109.658549      6.140762   2007.860773
# std    4.858721e+07  2.146698e+08    18.017041      0.764763      4.468841
# min    5.000000e+06  2.033165e+06    63.000000      3.300000   2000.000000
# 25%    2.000000e+07  3.456058e+07    97.000000      5.600000   2004.000000
# 50%    3.800000e+07  8.361541e+07   107.000000      6.100000   2008.000000
# 75%    7.200000e+07  1.782626e+08   120.000000      6.600000   2012.000000
# max    3.800000e+08  2.781506e+09   214.000000      8.100000   2015.000000

# %% [markdown]
# # Предобработка

# %%
answers = {} # создадим словарь для ответов

# тут другие ваши предобработки колонок например:

#the time given in the dataset is in string format.
#So we need to change this in datetime format
# Добавляем колонку 'Прибыль'
Movies.profit = Movies.revenue - Movies.budget
# Создаём список жанров
Genres = ['Action', 'Adventure', 'Drama', 'Comedy', 'Thriller']
# Создаём датафрейм прибыльных фильмов
profit_Movies = Movies[Movies.profit > 0].reset_index()
# Датафрейм высокобюджетных фильмов
high_budget_Movies = Movies[Movies.budget > Movies.budget.mean()]

# %% [markdown]
# # 1. У какого фильма из списка самый большой бюджет?

# %% [markdown]
# Использовать варианты ответов в коде решения запрещено.
# Вы думаете и в жизни у вас будут варианты ответов?)

# %%
# Словарь ответов
answers['1'] = 'Pirates of the Caribbean: On Stranger Tides (tt1298650)' # "+"

# %%
# тут пишем ваш код для решения данного вопроса:
Movies[Movies.budget == Movies.budget.max()].original_title
# Out:
# 723    Pirates of the Caribbean: On Stranger Tides
# Name: original_title, dtype: object

# %% [markdown]
# ВАРИАНТ 2

# %%
# можно добавлять разные варианты решения

# %% [markdown]
# # 2. Какой из фильмов самый длительный (в минутах)?

# %%
answers['2'] = 'Gods and Generals (tt0279111)' # "+"

# %%
Movies[Movies.runtime == Movies.runtime.max()].original_title
# Out:
# 1157    Gods and Generals
# Name: original_title, dtype: object

# %% [markdown]
# # 3. Какой из фильмов самый короткий (в минутах)?

# %%
answers['3'] = 'Winnie the Pooh (tt1449283)' # "+"

# %%
Movies[Movies.runtime == Movies.runtime.min()].original_title
# Out:
# 768    Winnie the Pooh
# Name: original_title, dtype: object

# %% [markdown]
# # 4. Какова средняя длительность фильмов?

# %%
answers['4'] = '110' # "+"

# %%
Movies.runtime.mean()
# Out:
# 109.6585494970884

# %% [markdown]
# # 5. Каково медианное значение длительности фильмов?

# %%
answers['5'] = '107' # "+"

# %%
Movies.runtime.describe()
# Out:
# count    1889.000000
# mean      109.658549
# std        18.017041
# min        63.000000
# 25%        97.000000
# 50%       107.000000
# 75%       120.000000
# max       214.000000
# Name: runtime, dtype: float64

# %% [markdown]
# # 6. Какой самый прибыльный фильм?
# #### Внимание! Здесь и далее под «прибылью» или «убытками» понимается разность между сборами и бюджетом фильма. (прибыль = сборы - бюджет) в нашем датасете это будет (profit = revenue - budget)

# %%
# лучше код получения столбца profit вынести в Предобработку что в начале
answers['6'] = 'Avatar (tt0499549)' # "+"

# %%
Movies[Movies.profit == Movies.profit.max()].original_title
# Out:
# 239    Avatar
# Name: original_title, dtype: object

# %% [markdown]
# # 7. Какой фильм самый убыточный?

# %%
answers['7'] = 'The Lone Ranger (tt1210819)' # "+"

# %%
Movies[Movies.profit == Movies.profit.min()].original_title
# Out:
# 1245    The Lone Ranger
# Name: original_title, dtype: object

# %% [markdown]
# # 8. У скольких фильмов из датасета объем сборов оказался выше бюджета?

# %%
answers['8'] = '1478' # "+"

# %%
Movies[Movies.revenue - Movies.budget > 0].imdb_id.count()
# Out:
# 1478

# %% [markdown]
# # 9. Какой фильм оказался самым кассовым в 2008 году?

# %%
answers['9'] = 'The Dark Knight (tt0468569)' # "+"

# %%
Movies_2008 = Movies[Movies.release_year == 2008]
Movies_2008[Movies_2008.revenue == Movies_2008.revenue.max()].original_title
# Out:
# 599    The Dark Knight
# Name: original_title, dtype: object

# %% [markdown]
# # 10. Самый убыточный фильм за период с 2012 по 2014 г. (включительно)?

# %%
answers['10'] = 'The Lone Ranger (tt1210819)' # "+"

# %%
Movies_12_14 = Movies[(Movies.release_year > 2011) & (Movies.release_year < 2015)]
Movies_12_14.profit = Movies_12_14.revenue - Movies_12_14.budget
Movies_12_14[Movies_12_14.profit == Movies_12_14.profit.min()].original_title
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
# 1245    The Lone Ranger
# Name: original_title, dtype: object

# %% [markdown]
# # 11. Какого жанра фильмов больше всего?

# %%
# эту задачу тоже можно решать разными подходами, попробуй реализовать разные варианты
# если будешь добавлять функцию - выноси ее в предобработку что в начале
answers['11'] = 'Drama' # "+"

# %%
# Список жанров вынесен в Предобработку
for Genre in Genres:
    print(Genre, Movies[Movies.genres.str.contains(Genre, na=False)].imdb_id.count())
# Out:
# Action 582
# Adventure 415
# Drama 782
# Comedy 683
# Thriller 596

# %% [markdown]
# ВАРИАНТ 2

# %% [markdown]
# # 12. Фильмы какого жанра чаще всего становятся прибыльными?

# %%
answers['12'] = 'Drama' # "+"

# %%
# Датафрейм прибыльных фильмов создан в предобработке
for Genre in Genres:
    print(Genre, profit_Movies[profit_Movies.genres.str.contains(Genre, na=False)].imdb_id.count())
# Out:
# Action 444
# Adventure 337
# Drama 560
# Comedy 551
# Thriller 446

# %% [markdown]
# # 13. У какого режиссера самые большие суммарные кассовые сборы?

# %%
answers['13'] = 'Peter Jackson' # "+"

# %%
grouped_director = Movies.groupby(['director'])['revenue'].sum().sort_values(ascending=False)
grouped_director.head(5)
# Out:
# director
# Peter Jackson        6490593685
# Christopher Nolan    4167548502
# David Yates          4154295625
# Michael Bay          3886938960
# J.J. Abrams          3579169916
# Name: revenue, dtype: int64

# %% [markdown]
# # 14. Какой режисер снял больше всего фильмов в стиле Action?

# %%
answers['14'] = 'Robert Rodriguez' # "+" Со второй попытки, т.к. есть еще Tony Scott

# %%
Movies[Movies.genres.str.match("Action", na=False)].director.value_counts().head(5)
# Out:
# Antoine Fuqua         5
# Tony Scott            5
# Robert Rodriguez      5
# Andrzej Bartkowiak    5
# Justin Lin            4
# Name: director, dtype: int64

# %% [markdown]
# # 15. Фильмы с каким актером принесли самые высокие кассовые сборы в 2012 году?

# %%
answers['15'] = 'Chris Hemsworth' # "+"

# %%
# Фильмы 2012 года
Movies_2012 = Movies[Movies.release_year == 2012]
# 1-й список актёров
Actors_1 = ['Nicolas Cage', 'Tom Hardy', 'Chris Hemsworth', 'Jim Sturgess', 'Emma Stone']
for Actor in Actors_1:
    print(Actor, Movies_2012[Movies_2012.cast.str.contains(Actor, na=False)]['revenue'].sum())
# Out:
# Nicolas Cage 2106557
# Tom Hardy 1134717867
# Chris Hemsworth 2027450773
# Jim Sturgess 138589343
# Emma Stone 752215857

# %% [markdown]
# # 16. Какой актер снялся в большем количестве высокобюджетных фильмов?

# %%
answers['16'] = 'Matt Damon' # "+"

# %%
# Датафрейм высокобюджетных фильмов создан в Предобработке
Actors_2 = ['Tom Cruise', 'Mark Wahlberg', 'Matt Damon', 'Angelina Jolie', 'Adam Sandler']
for Actor in Actors_2:
    print(Actor, high_budget_Movies[high_budget_Movies.cast.str.contains(Actor, na=False)]['revenue'].count())
# Out:
# Tom Cruise 15
# Mark Wahlberg 14
# Matt Damon 18
# Angelina Jolie 16
# Adam Sandler 17

# %% [markdown]
# # 17. В фильмах какого жанра больше всего снимался Nicolas Cage?

# %%
answers['17'] = 'Action' # "+"

# %%
# Датафрейм фильмов с Николасом Кейджем
Nicolas_Cage = Movies[Movies.cast.str.contains("Nicolas Cage", na=False)]
for Genre in Genres:
    print(Genre, Nicolas_Cage[Nicolas_Cage.genres.str.contains(Genre, na=False)].imdb_id.count())
# Out:
# Action 17
# Adventure 7
# Drama 12
# Comedy 6
# Thriller 15

# %% [markdown]
# # 18. Самый убыточный фильм от Paramount Pictures

# %%
answers['18'] = 'K-19: The Widowmaker (tt0267626)' # "+"

# %%
Paramount_Pictures = Movies[Movies.production_companies.str.contains("Paramount Pictures", na=False)].reset_index()
Paramount_Pictures['profit'] = Paramount_Pictures['budget'] - Paramount_Pictures['revenue']
print(Paramount_Pictures[Paramount_Pictures.profit == Paramount_Pictures.profit.min()].original_title)
# Out:
# 47    Transformers: Dark of the Moon
# Name: original_title, dtype: object

# %% [markdown]
# # 19. Какой год стал самым успешным по суммарным кассовым сборам?

# %%
answers['19'] = '2015' # "+"

# %%
grouped_revenue = Movies.groupby(['release_year'])['revenue'].sum().sort_values(ascending=False)
grouped_revenue.head(5)
# Out:
# release_year
# 2015    25449202382
# 2014    23405862953
# 2013    23213799791
# 2012    23079001687
# 2011    22676791872
# Name: revenue, dtype: int64

# %% [markdown]
# # 20. Какой самый прибыльный год для студии Warner Bros?

# %%
answers['20'] = '2014' # "+"

# %%
# Датафрейм фильмов студии Warner Bros
Warner_Bros = Movies[Movies.production_companies.str.contains("Warner Bros", na=False)].reset_index()
grouped_revenue_WB = Warner_Bros.groupby(['release_year'])['revenue'].sum().sort_values(ascending=False)
grouped_revenue_WB.head(5)
# Out:
# release_year
# 2014    3243064519
# 2007    3183675217
# 2008    3050595031
# 2010    3008712985
# 2011    2845393682
# Name: revenue, dtype: int64

# %% [markdown]
# # 21. В каком месяце за все годы суммарно вышло больше всего фильмов?

# %%
answers['21'] = 'Сентябрь' # "+"

# %%
# Список месяцев
Months = ['1/', '5', '6', '9', '12']
for Month in Months:
  print(Month, Movies[Movies.release_date.str.match(Month, na=False)].imdb_id.count())
# Out:
# 1/ 110
# 5 140
# 6 147
# 9 227
# 12 190

# %% [markdown]
# # 22. Сколько суммарно вышло фильмов летом? (за июнь, июль, август)

# %%
answers['22'] = '450' # "+"

# %%
print(sum([ Movies[Movies.release_date.str.match(str(month), na=False)].imdb_id.count() for month in [6, 7, 8] ]))
# Out:
# 450

# %% [markdown]
# # 23. Для какого режиссера зима – самое продуктивное время года?

# %%
answers['23'] = 'Peter Jackson' # "+"

# %%
# Список режиссеров
directors = ['Steven Soderbergh', 'Christopher Nolan', 'Clint Eastwood', 'Ridley Scott', 'Peter Jackson']
for director in directors:
    print(director, sum([ Movies[Movies.release_date.str.match((str(month)+'/') or ((str(month)+'.')), na=False)
                  & (Movies.director == director)].imdb_id.count() for month in [1, 2, 12] ]))
# Out:
# Steven Soderbergh 6
# Christopher Nolan 0
# Clint Eastwood 6
# Ridley Scott 3
# Peter Jackson 7

# %% [markdown]
# # 24. Какая студия дает самые длинные названия своим фильмам по количеству символов?

# %%
answers['24'] = 'Four By Two Productions' # "+"

# %%
# 1-й Список студий
studios_1 = ['Universal Pictures', 'Warner Bros', 'Jim Henson Company, The', 'Paramount Pictures', 'Four By Two Productions']
for studio in studios_1:
    studio_df = Movies[Movies.production_companies.str.contains(studio, na=False)].reset_index()
    print(studio, studio_df.original_title.str.len().mean())
# Out:
# Universal Pictures 14.731428571428571
# Warner Bros 15.251366120218579
# Jim Henson Company, The 59.0
# Paramount Pictures 17.0327868852459
# Four By Two Productions 83.0

# %% [markdown]
# # 25. Описание фильмов какой студии в среднем самые длинные по количеству слов?

# %%
answers['25'] = 'Midnight Picture Show' # "+"

# %%
# 2-й список студий
studios_2 = ['Universal Pictures', 'Warner Bros', 'Midnight Picture Show', 'Paramount Pictures', 'Total Entertainment']
for studio in studios_2:
    studio_df = Movies[Movies.production_companies.str.contains(studio, na=False)].reset_index()
    print(studio, studio_df.overview.str.len().mean())
# Out:
# Universal Pictures 315.46285714285716
# Warner Bros 318.2568306010929
# Midnight Picture Show 1000.0
# Paramount Pictures 323.3114754098361
# Total Entertainment 526.0

# %% [markdown]
# # 26. Какие фильмы входят в 1 процент лучших по рейтингу?
# по vote_average

# %%
answers['26'] = 'Batman Begins, The Lord of the Rings: The Return of the King, Upside Down' # "-"

# %%
Movies = [['Inside Out', 'The Dark Knight', '12 Years a Slave'], ['BloodRayne', 'The Adventures of Rocky & Bullwinkle'],
          ['Batman Begins', 'The Lord of the Rings: The Return of the King', 'Upside Down'],
          ['300', 'Lucky Number Slevin', 'Kill Bill: Vol. 1'], ['Upside Down', 'Inside Out', 'Iron Man']]

# %% [markdown]
# # 27. Какие актеры чаще всего снимаются в одном фильме вместе?

# %%
answers['27'] = 'Daniel Radcliffe & Rupert Grint'  # "+"

# %%
# 3-й список актёров
actors_3 = [['Johnny Depp', 'Helena Bonham Carter'], ['Ben Stiller', 'Owen Wilson'], ['Vin Diesel', 'Paul Walker'],
          ['Adam Sandler', 'Kevin James'], ['Daniel Radcliffe', 'Rupert Grint']]
for pair in actors_3:
    print(pair, Movies[Movies.cast.str.contains(pair[0], na=False) &
                       Movies.cast.str.contains(pair[1], na=False)].imdb_id.count())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-189-cdfabbfd8ea7> in <module>()
#       3           ['Adam Sandler', 'Kevin James'], ['Daniel Radcliffe', 'Rupert Grint']]
#       4 for pair in actors_3:
# ----> 5     print(pair, Movies[Movies.cast.str.contains(pair[0], na=False) &
#       6                        Movies.cast.str.contains(pair[1], na=False)].imdb_id.count())
#
# AttributeError: 'list' object has no attribute 'cast'

# %% [markdown]
# ВАРИАНТ 2

# %% [markdown]
# # Submission

# %%
# в конце можно посмотреть свои ответы к каждому вопросу
answers
# Out:
# {'1': 'Pirates of the Caribbean: On Stranger Tides (tt1298650)',
#  '10': 'The Lone Ranger (tt1210819)',
#  '11': 'Drama',
#  '12': 'Drama',
#  '13': 'Peter Jackson',
#  '14': 'Robert Rodriguez',
#  '15': 'Chris Hemsworth',
#  '16': 'Matt Damon',
#  '17': 'Action',
#  '18': 'K-19: The Widowmaker (tt0267626)',
#  '19': '2015',
#  '2': 'Gods and Generals (tt0279111)',
#  '20': '2014',
#  '21': 'Сентябрь',
#  '22': '450',
#  '23': 'Peter Jackson',
#  '24': 'Four By Two Productions',
#  '25': 'Midnight Picture Show',
#  '26': 'Batman Begins, The Lord of the Rings: The Return of the King, Upside Down',
#  '27': 'Daniel Radcliffe & Rupert Grint',
#  '3': 'Winnie the Pooh (tt1449283)',
#  '4': '110',
#  '5': '107',
#  '6': 'Avatar (tt0499549)',
#  '7': 'The Lone Ranger (tt1210819)',
#  '8': '1478',
#  '9': 'The Dark Knight (tt0468569)'}

# %%
# и убедиться что ни чего не пропустил)
len(answers)
# Out:
# 27
